# %%
using Plots
using JLD2

# %%
d = load("$(@__DIR__)/data1D/gridSensitivity1D_singlePerturbation.jld2");
res = d["res"];
eigs = d["eigs"];
Ns = d["Ns"];
weightStr = d["weightStr"];
randomnessArr = d["randomnessArr"];
algs = d["algs"];
orders = d["orders"];

# %%
stabilityRes = map(x -> x == 0, res);

# %%
println(algs)
println(orders)
# Out:
# ["central", "central", "upwind", "upwind", "muscl", "muscl", "muscl", "muscl"]
# [1, 2, 1, 2, 1, 2, 3, 4]

# %%
algIndex = 7
weight1Index = 1
NIndex = 2
plot(randomnessArr, stabilityRes[:, weight1Index, NIndex, algIndex], label="N = $(Ns[NIndex]), Alg: $(algs[algIndex]) $(orders[algIndex])", ylim = (-0.05, 1.05), lt=:scatter)
